# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/physics/blob/20250522-1/%EC%98%88%EC%A0%9C_5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

mass = 0.15
radius = 0.60
frequency = 2.0

T = 1 / frequency
print(f"(a) 주기 T = {T:.2f} s")

v = 2 * math.pi * radius / T
print(f"(b) 속력 v = {v:.2f} m/s")

a_c = v ** 2 / radius
print(f"(c) 구심가속도 a_c = {a_c:.2f} m/s²")
# Out:
# (a) 주기 T = 0.50 s
# (b) 속력 v = 7.54 m/s
# (c) 구심가속도 a_c = 94.75 m/s²
