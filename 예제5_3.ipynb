# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/physics/blob/20250522-3/%EC%98%88%EC%A0%9C5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r = 500
t = 10.5
v_final = 32
v_current = 35

a_t = v_final / t
print(f"(a) 접선 가속도 a_t = {a_t:.2f} m/s²")

a_r = v_current ** 2 / r
print(f"(b) 지름 가속도 a_r = {a_r:.2f} m/s²")
# Out:
# (a) 접선 가속도 a_t = 3.05 m/s²
# (b) 지름 가속도 a_r = 2.45 m/s²
