# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/physics/blob/20250522-2/%EA%B4%80%EB%A0%A8_%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

theta_deg = 45
r = 20
g = 9.8

theta_rad = math.radians(theta_deg)
tan_theta = math.tan(theta_rad)

v_squared = r * g * tan_theta
v = math.sqrt(v_squared)

print(f"(1) θ = {theta_deg}°일 때, 속력 v = {v:.2f} m/s")

a_c = v_squared / r
print(f"(2) 구심가속도 a_c = {a_c:.2f} m/s²")
# Out:
# (1) θ = 45°일 때, 속력 v = 14.00 m/s
# (2) 구심가속도 a_c = 9.80 m/s²
