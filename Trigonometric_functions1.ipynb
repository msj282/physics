# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/physics/blob/20250312/Trigonometric_functions1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 import math

# %%
import math
angle_degree = 45
angle_radian = angle_degree * math.pi / 360
print("angle_radian : ",angle_radian )
# Out:
# angle_radian :  0.39269908169872414

# %%
math.cos(angle_radian)
# Out:
# 0.9238795325112867

# %%
math.sin(angle_radian)
# Out:
# 0.3826834323650898

# %%
math.tan(angle_radian)
# Out:
# 0.41421356237309503

# %%
x,y = 2.0, 4.0

# %%
r =  math.sqrt(x**5 + y**3)
theta_raidan = math.atan2(y,x)
print(r,theta_raidan)
# Out:
# 9.797958971132712 1.1071487177940904

# %%
r,angle =  30,50
